# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork20647850-2022-01-01">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product " />
# </a>

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/cc-logo-square.png" width="200" alt="cognitiveclass.ai logo" />

# %% [markdown]
# <h1><h1>Pre-trained-Models with PyTorch </h1>

# %% [markdown]
# In this lab, you will use pre-trained models to classify between the negative and positive samples; you will be provided with the dataset object. The particular pre-trained model will be resnet18; you will have three questions:
#
# <ul>
# <li>change the output layer</li>
# <li> train the model</li>
# <li>  identify  several  misclassified samples</li>
#  </ul>
# You will take several screenshots of your work and share your notebook.

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <ul>
#     <li><a href="https://#download_data"> Download Data</a></li>
#     <li><a href="https://#auxiliary"> Imports and Auxiliary Functions </a></li>
#     <li><a href="https://#data_class"> Dataset Class</a></li>
#     <li><a href="https://#Question_1">Question 1</a></li>
#     <li><a href="https://#Question_2">Question 2</a></li>
#     <li><a href="https://#Question_3">Question 3</a></li>
# </ul>
# <p>Estimated Time Needed: <strong>120 min</strong></p>
#  </div>
# <hr>

# %% [markdown]
# <h2 id="download_data">Download Data</h2>

# %% [markdown]
# Download the dataset and unzip the files in your data directory, unlike the other labs, all the data will be deleted after you close  the lab, this may take some time:

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Out:
# --2022-11-10 17:19:47--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2598656062 (2.4G) [application/zip]
# Saving to: ‘Positive_tensors.zip’
#
# Positive_tensors.zi 100%[===================>]   2.42G  38.0MB/s    in 72s
#
# 2022-11-10 17:21:00 (34.3 MB/s) - ‘Positive_tensors.zip’ saved [2598656062/2598656062]

# %%
# !unzip -q Positive_tensors.zip

# %%
! wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# !unzip -q Negative_tensors.zip
# Out:
# --2022-11-10 17:25:03--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2111408108 (2.0G) [application/zip]
# Saving to: ‘Negative_tensors.zip’
#
# Negative_tensors.zi 100%[===================>]   1.97G  32.4MB/s    in 62s
#
# 2022-11-10 17:26:06 (32.4 MB/s) - ‘Negative_tensors.zip’ saved [2111408108/2111408108]

# %% [markdown]
# We will install torchvision:

# %%
# !pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (0.11.3)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from torchvision) (1.20.3)
# Requirement already satisfied: torch in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from torchvision) (1.10.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from torchvision) (9.0.1)
# Requirement already satisfied: typing_extensions in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from torch->torchvision) (4.1.1)

# %% [markdown]
# <h2 id="auxiliary">Imports and Auxiliary Functions</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab. The <code>torch.manual_seed()</code> is for forcing the random function to give the same number every time we try to recompile it.

# %%
# These are the libraries will be used for this lab.
import torchvision.models as models
from PIL import Image
import pandas
from torchvision import transforms
import torch.nn as nn
import time
import torch 
import matplotlib.pylab as plt
import numpy as np
from torch.utils.data import Dataset, DataLoader
import h5py
import os
import glob
torch.manual_seed(0)

# %%
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt
from PIL import Image
import pandas as pd
import os

# %%
pwd
# Out:
# '/home/wsuser/work'

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="data_class">Dataset Class</h2>

# %% [markdown]
# This dataset class is essentially the same dataset you build in the previous section, but to speed things up, we are going to use tensors instead of jpeg images. Therefor for each iteration, you will skip the reshape step, conversion step to tensors and normalization step.

# %%
# Create your own dataset object

class Dataset(Dataset):

    # Constructor
    def __init__(self,transform=None,train=True):
        directory="/home/wsuser/work"
        positive="Positive_tensors"
        negative='Negative_tensors'

        positive_file_path=os.path.join(directory,positive)
        negative_file_path=os.path.join(directory,negative)
        positive_files=[os.path.join(positive_file_path,file) for file in os.listdir(positive_file_path) if file.endswith(".pt")]
        negative_files=[os.path.join(negative_file_path,file) for file in os.listdir(negative_file_path) if file.endswith(".pt")]
        number_of_samples=len(positive_files)+len(negative_files)
        self.all_files=[None]*number_of_samples
        self.all_files[::2]=positive_files
        self.all_files[1::2]=negative_files 
        # The transform is goint to be used on image
        self.transform = transform
        #torch.LongTensor
        self.Y=torch.zeros([number_of_samples]).type(torch.LongTensor)
        self.Y[::2]=1
        self.Y[1::2]=0
        
        if train:
            self.all_files=self.all_files[0:30000]
            self.Y=self.Y[0:30000]
            self.len=len(self.all_files)
        else:
            self.all_files=self.all_files[30000:]
            self.Y=self.Y[30000:]
            self.len=len(self.all_files)     
       
    # Get the length
    def __len__(self):
        return self.len
    
    # Getter
    def __getitem__(self, idx):
               
        image=torch.load(self.all_files[idx])
        y=self.Y[idx]
                  
        # If there is any transform method, apply it onto the image
        if self.transform:
            image = self.transform(image)

        return image, y
    
print("done")
# Out:
# done

# %% [markdown]
# We create two dataset objects, one for the training data and one for the validation data.

# %%
train_dataset = Dataset(train=True)
validation_dataset = Dataset(train=False)
print("done")
# Out:
# done

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>

# %% [markdown]
# <b>Prepare a pre-trained resnet18 model :</b>

# %% [markdown]
# <b>Step 1</b>: Load the pre-trained model <code>resnet18</code> Set the parameter <code>pretrained</code> to true:

# %%
# Step 1: Load the pre-trained model resnet18

# Type your code here
model=models.resnet18(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/wsuser/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %% [markdown]
# <b>Step 2</b>: Set the attribute <code>requires_grad</code> to <code>False</code>. As a result, the parameters will not be affected by training.

# %%
# Step 2: Set the parameter cannot be trained for the pre-trained model


# Type your code here
for param in model.parameters():
    param.requires_grad = False

# %% [markdown]
# <code>resnet18</code> is used to classify 1000 different objects; as a result, the last layer has 1000 outputs.  The 512 inputs come from the fact that the previously hidden layer has 512 outputs.

# %% [markdown]
# <b>Step 3</b>: Replace the output layer <code>model.fc</code> of the neural network with a <code>nn.Linear</code> object, to classify 2 different classes. For the parameters <code>in_features </code> remember the last hidden layer has 512 neurons.

# %%
model.fc = nn.Linear(512, 2)

# %% [markdown]
# Print out the model in order to show whether you get the correct answer.<br> <b>(Your peer reviewer is going to mark based on what you print here.)</b>

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)
print(model)
print(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )
# cpu

# %% [markdown]
# <h2 id="Question_2">Question 2: Train the Model</h2>

# %% [markdown]
# In this question you will train your, model:

# %% [markdown]
# <b>Step 1</b>: Create a cross entropy criterion function

# %%
# Step 1: Create the loss function

# Type your code here
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# <b>Step 2</b>: Create a training loader and validation loader object, the batch size should have 100 samples each.

# %%
train_loader = torch.utils.data.DataLoader(dataset = train_dataset, batch_size = 100)
validation_loader = torch.utils.data.DataLoader(dataset = validation_dataset, batch_size=100)

for param in model.parameters():
    if param.requires_grad:
        print(param)
# Out:
# Parameter containing:
# tensor([[ 0.0342, -0.0255,  0.0249,  ...,  0.0130, -0.0365, -0.0426],
#         [ 0.0411, -0.0204,  0.0384,  ...,  0.0156, -0.0340,  0.0069]],
#        requires_grad=True)
# Parameter containing:
# tensor([0.0074, 0.0091], requires_grad=True)

# %% [markdown]
# <b>Step 3</b>: Use the following optimizer to minimize the loss

# %%
optimizer = torch.optim.Adam([parameters  for parameters in model.parameters() if parameters.requires_grad],lr=0.001)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# **Complete the following code to calculate  the accuracy on the validation data for one epoch; this should take about 45 minutes. Make sure you calculate the accuracy on the validation data.**

# %%
n_epochs=1
loss_list=[]
accuracy_list=[]
correct=0
accuracy = 0
N_test=len(validation_dataset)
N_train=len(train_dataset)
start_time = time.time()
batch_size =100
#n_epochs

run_loss = 0
for epoch in range(n_epochs):
    for i, (x, y) in enumerate(train_loader):
        print('-'*40)
        print("Iteration, for train phase {}/{}".format(i+1, int(N_train/batch_size)))
        i_start_time = time.time()
        x, y = x.to(device), y.to(device)

        model.train() 
        #clear gradient
        optimizer.zero_grad()
     
        #make a prediction
        z = model(x)
   
        # calculate loss
        loss = criterion(z, y)
    
        # calculate gradients of parameters
        loss.backward()
        
        
        # update parameters 
        optimizer.step()
        loss_list.append(loss.data)
        print("The time taken is {} seconds".format(time.time()-i_start_time))
    correct=0
    for i, (x_test, y_test) in enumerate(validation_loader):
        print('-'*40)
        print("Iteration, for validation phase {}/{}".format(i+1, int(N_test/batch_size)))
        i_start_time = time.time()
        x_test, y_test = x_test.to(device), y_test.to(device)
        # set model to eval
        model.eval()
       
        #make a prediction
        z = model(x_test)
        
        #find max
        _, yhat = torch.max(z.data, 1)
       
       
        #Calculate misclassified  samples in mini-batch 
        #hint +=(yhat==y_test).sum().item()
        correct += (yhat==y_test).sum().item()
        print("The time taken is {} seconds".format(time.time()-i_start_time))
        
   
    accuracy=correct/N_test
    accuracy_list.append(accuracy)
    print("The accuracy of the model is: {}".format(accuracy))
# Out:
# ----------------------------------------
# Iteration, for train phase 1/300
# The time taken is 16.897080421447754 seconds
# ----------------------------------------
# Iteration, for train phase 2/300
# The time taken is 16.501080989837646 seconds
# ----------------------------------------
# Iteration, for train phase 3/300
# The time taken is 16.554567337036133 seconds
# ----------------------------------------
# Iteration, for train phase 4/300
# The time taken is 18.072957754135132 seconds
# ----------------------------------------
# Iteration, for train phase 5/300
# The time taken is 16.705284357070923 seconds
# ----------------------------------------
# Iteration, for train phase 6/300
# The time taken is 18.119994401931763 seconds
# ----------------------------------------
# Iteration, for train phase 7/300
# The time taken is 17.237141370773315 seconds
# ----------------------------------------
# Iteration, for train phase 8/300
# The time taken is 17.513721227645874 seconds
# ----------------------------------------
# Iteration, for train phase 9/300
# The time taken is 16.31740951538086 seconds
# ----------------------------------------
# Iteration, for train phase 10/300
# The time taken is 17.237372398376465 seconds
# ----------------------------------------
# Iteration, for train phase 11/300
# The time taken is 17.256147861480713 seconds
# ----------------------------------------
# Iteration, for train phase 12/300
# The time taken is 17.397213220596313 seconds
# ----------------------------------------
# Iteration, for train phase 13/300
# The time taken is 17.495808601379395 seconds
# ----------------------------------------
# Iteration, for train phase 14/300
# The time taken is 16.65102195739746 seconds
# ----------------------------------------
# Iteration, for train phase 15/300
# The time taken is 16.16714644432068 seconds
# ----------------------------------------
# Iteration, for train phase 16/300
# The time taken is 16.616616249084473 seconds
# ----------------------------------------
# Iteration, for train phase 17/300
# The time taken is 16.398927211761475 seconds
# ----------------------------------------
# Iteration, for train phase 18/300
# The time taken is 16.758272171020508 seconds
# ----------------------------------------
# Iteration, for train phase 19/300
# The time taken is 16.78031086921692 seconds
# ----------------------------------------
# Iteration, for train phase 20/300
# The time taken is 16.943401336669922 seconds
# ----------------------------------------
# Iteration, for train phase 21/300
# The time taken is 17.087950468063354 seconds
# ----------------------------------------
# Iteration, for train phase 22/300
# The time taken is 16.00224733352661 seconds
# ----------------------------------------
# Iteration, for train phase 23/300
# The time taken is 16.608689785003662 seconds
# ----------------------------------------
# Iteration, for train phase 24/300
# The time taken is 16.799450159072876 seconds
# ----------------------------------------
# Iteration, for train phase 25/300
# The time taken is 15.718780040740967 seconds
# ----------------------------------------
# Iteration, for train phase 26/300
# The time taken is 16.218419075012207 seconds
# ----------------------------------------
# Iteration, for train phase 27/300
# The time taken is 18.38631558418274 seconds
# ----------------------------------------
# Iteration, for train phase 28/300
# The time taken is 18.523879289627075 seconds
# ----------------------------------------
# Iteration, for train phase 29/300
# The time taken is 17.279236316680908 seconds
# ----------------------------------------
# Iteration, for train phase 30/300
# The time taken is 17.44944190979004 seconds
# ----------------------------------------
# Iteration, for train phase 31/300
# The time taken is 16.975650787353516 seconds
# ----------------------------------------
# Iteration, for train phase 32/300
# The time taken is 16.608641147613525 seconds
# ----------------------------------------
# Iteration, for train phase 33/300
# The time taken is 16.83607578277588 seconds
# ----------------------------------------
# Iteration, for train phase 34/300
# The time taken is 17.350364208221436 seconds
# ----------------------------------------
# Iteration, for train phase 35/300
# The time taken is 17.340513467788696 seconds
# ----------------------------------------
# Iteration, for train phase 36/300
# The time taken is 16.218719244003296 seconds
# ----------------------------------------
# Iteration, for train phase 37/300
# The time taken is 17.109838724136353 seconds
# ----------------------------------------
# Iteration, for train phase 38/300
# The time taken is 16.435887575149536 seconds
# ----------------------------------------
# Iteration, for train phase 39/300
# The time taken is 16.737178802490234 seconds
# ----------------------------------------
# Iteration, for train phase 40/300
# The time taken is 16.720686197280884 seconds
# ----------------------------------------
# Iteration, for train phase 41/300
# The time taken is 18.709558725357056 seconds
# ----------------------------------------
# Iteration, for train phase 42/300
# The time taken is 16.90826439857483 seconds
# ----------------------------------------
# Iteration, for train phase 43/300
# The time taken is 16.261935710906982 seconds
# ----------------------------------------
# Iteration, for train phase 44/300
# The time taken is 19.15492868423462 seconds
# ----------------------------------------
# Iteration, for train phase 45/300
# The time taken is 17.07785964012146 seconds
# ----------------------------------------
# Iteration, for train phase 46/300
# The time taken is 16.93015694618225 seconds
# ----------------------------------------
# Iteration, for train phase 47/300
# The time taken is 18.076444625854492 seconds
# ----------------------------------------
# Iteration, for train phase 48/300
# The time taken is 18.713869094848633 seconds
# ----------------------------------------
# Iteration, for train phase 49/300
# The time taken is 16.779493808746338 seconds
# ----------------------------------------
# Iteration, for train phase 50/300
# The time taken is 16.95909810066223 seconds
# ----------------------------------------
# Iteration, for train phase 51/300
# The time taken is 16.703383207321167 seconds
# ----------------------------------------
# Iteration, for train phase 52/300
# The time taken is 17.497678995132446 seconds
# ----------------------------------------
# Iteration, for train phase 53/300
# The time taken is 16.62110424041748 seconds
# ----------------------------------------
# Iteration, for train phase 54/300
# The time taken is 17.54529070854187 seconds
# ----------------------------------------
# Iteration, for train phase 55/300
# The time taken is 16.243893146514893 seconds
# ----------------------------------------
# Iteration, for train phase 56/300
# The time taken is 16.876359939575195 seconds
# ----------------------------------------
# Iteration, for train phase 57/300
# The time taken is 21.336789846420288 seconds
# ----------------------------------------
# Iteration, for train phase 58/300
# The time taken is 17.28404426574707 seconds
# ----------------------------------------
# Iteration, for train phase 59/300
# The time taken is 15.835285186767578 seconds
# ----------------------------------------
# Iteration, for train phase 60/300
# The time taken is 17.160846710205078 seconds
# ----------------------------------------
# Iteration, for train phase 61/300
# The time taken is 18.21400499343872 seconds
# ----------------------------------------
# Iteration, for train phase 62/300
# The time taken is 17.149399042129517 seconds
# ----------------------------------------
# Iteration, for train phase 63/300
# The time taken is 16.759578704833984 seconds
# ----------------------------------------
# Iteration, for train phase 64/300
# The time taken is 17.23379111289978 seconds
# ----------------------------------------
# Iteration, for train phase 65/300
# The time taken is 18.196441173553467 seconds
# ----------------------------------------
# Iteration, for train phase 66/300
# The time taken is 16.95054054260254 seconds
# ----------------------------------------
# Iteration, for train phase 67/300
# The time taken is 17.166154623031616 seconds
# ----------------------------------------
# Iteration, for train phase 68/300
# The time taken is 18.150474071502686 seconds
# ----------------------------------------
# Iteration, for train phase 69/300
# The time taken is 16.3265221118927 seconds
# ----------------------------------------
# Iteration, for train phase 70/300
# The time taken is 16.152488231658936 seconds
# ----------------------------------------
# Iteration, for train phase 71/300
# The time taken is 16.18704915046692 seconds
# ----------------------------------------
# Iteration, for train phase 72/300
# The time taken is 16.480754137039185 seconds
# ----------------------------------------
# Iteration, for train phase 73/300
# The time taken is 17.986061334609985 seconds
# ----------------------------------------
# Iteration, for train phase 74/300
# The time taken is 17.031548500061035 seconds
# ----------------------------------------
# Iteration, for train phase 75/300
# The time taken is 16.754425048828125 seconds
# ----------------------------------------
# Iteration, for train phase 76/300
# The time taken is 18.749047994613647 seconds
# ----------------------------------------
# Iteration, for train phase 77/300
# The time taken is 17.392082691192627 seconds
# ----------------------------------------
# Iteration, for train phase 78/300
# The time taken is 17.26351046562195 seconds
# ----------------------------------------
# Iteration, for train phase 79/300
# The time taken is 16.48368263244629 seconds
# ----------------------------------------
# Iteration, for train phase 80/300
# The time taken is 16.451788663864136 seconds
# ----------------------------------------
# Iteration, for train phase 81/300
# The time taken is 18.41971468925476 seconds
# ----------------------------------------
# Iteration, for train phase 82/300
# The time taken is 16.73961305618286 seconds
# ----------------------------------------
# Iteration, for train phase 83/300
# The time taken is 16.82526707649231 seconds
# ----------------------------------------
# Iteration, for train phase 84/300
# The time taken is 16.76841115951538 seconds
# ----------------------------------------
# Iteration, for train phase 85/300
# The time taken is 21.773860692977905 seconds
# ----------------------------------------
# Iteration, for train phase 86/300
# The time taken is 17.163623094558716 seconds
# ----------------------------------------
# Iteration, for train phase 87/300
# The time taken is 17.118521690368652 seconds
# ----------------------------------------
# Iteration, for train phase 88/300
# The time taken is 16.64537286758423 seconds
# ----------------------------------------
# Iteration, for train phase 89/300
# The time taken is 17.210745811462402 seconds
# ----------------------------------------
# Iteration, for train phase 90/300
# The time taken is 16.404608488082886 seconds
# ----------------------------------------
# Iteration, for train phase 91/300
# The time taken is 17.268721103668213 seconds
# ----------------------------------------
# Iteration, for train phase 92/300
# The time taken is 18.848499059677124 seconds
# ----------------------------------------
# Iteration, for train phase 93/300
# The time taken is 18.079516887664795 seconds
# ----------------------------------------
# Iteration, for train phase 94/300
# The time taken is 17.608176231384277 seconds
# ----------------------------------------
# Iteration, for train phase 95/300
# The time taken is 17.317806720733643 seconds
# ----------------------------------------
# Iteration, for train phase 96/300
# The time taken is 16.207475423812866 seconds
# ----------------------------------------
# Iteration, for train phase 97/300
# The time taken is 18.101683855056763 seconds
# ----------------------------------------
# Iteration, for train phase 98/300
# The time taken is 18.84208369255066 seconds
# ----------------------------------------
# Iteration, for train phase 99/300
# The time taken is 18.43120837211609 seconds
# ----------------------------------------
# Iteration, for train phase 100/300
# The time taken is 16.94670844078064 seconds
# ----------------------------------------
# Iteration, for train phase 101/300
# The time taken is 17.15327286720276 seconds
# ----------------------------------------
# Iteration, for train phase 102/300
# The time taken is 16.846359252929688 seconds
# ----------------------------------------
# Iteration, for train phase 103/300
# The time taken is 16.54828190803528 seconds
# ----------------------------------------
# Iteration, for train phase 104/300
# The time taken is 16.975813150405884 seconds
# ----------------------------------------
# Iteration, for train phase 105/300
# The time taken is 16.782167434692383 seconds
# ----------------------------------------
# Iteration, for train phase 106/300
# The time taken is 16.075679063796997 seconds
# ----------------------------------------
# Iteration, for train phase 107/300
# The time taken is 16.94941234588623 seconds
# ----------------------------------------
# Iteration, for train phase 108/300
# The time taken is 17.27856469154358 seconds
# ----------------------------------------
# Iteration, for train phase 109/300
# The time taken is 16.82431125640869 seconds
# ----------------------------------------
# Iteration, for train phase 110/300
# The time taken is 16.32638430595398 seconds
# ----------------------------------------
# Iteration, for train phase 111/300
# The time taken is 17.451274871826172 seconds
# ----------------------------------------
# Iteration, for train phase 112/300
# The time taken is 16.983003616333008 seconds
# ----------------------------------------
# Iteration, for train phase 113/300
# The time taken is 16.353981971740723 seconds
# ----------------------------------------
# Iteration, for train phase 114/300
# The time taken is 16.93172860145569 seconds
# ----------------------------------------
# Iteration, for train phase 115/300
# The time taken is 17.025855779647827 seconds
# ----------------------------------------
# Iteration, for train phase 116/300
# The time taken is 16.31917643547058 seconds
# ----------------------------------------
# Iteration, for train phase 117/300
# The time taken is 17.617783546447754 seconds
# ----------------------------------------
# Iteration, for train phase 118/300
# The time taken is 16.30765676498413 seconds
# ----------------------------------------
# Iteration, for train phase 119/300
# The time taken is 16.611336708068848 seconds
# ----------------------------------------
# Iteration, for train phase 120/300
# The time taken is 16.637372255325317 seconds
# ----------------------------------------
# Iteration, for train phase 121/300
# The time taken is 16.16691303253174 seconds
# ----------------------------------------
# Iteration, for train phase 122/300
# The time taken is 16.45742392539978 seconds
# ----------------------------------------
# Iteration, for train phase 123/300
# The time taken is 17.091822147369385 seconds
# ----------------------------------------
# Iteration, for train phase 124/300
# The time taken is 16.936464548110962 seconds
# ----------------------------------------
# Iteration, for train phase 125/300
# The time taken is 17.208410501480103 seconds
# ----------------------------------------
# Iteration, for train phase 126/300
# The time taken is 17.251975774765015 seconds
# ----------------------------------------
# Iteration, for train phase 127/300
# The time taken is 15.832587957382202 seconds
# ----------------------------------------
# Iteration, for train phase 128/300
# The time taken is 19.576984882354736 seconds
# ----------------------------------------
# Iteration, for train phase 129/300
# The time taken is 16.828014135360718 seconds
# ----------------------------------------
# Iteration, for train phase 130/300
# The time taken is 16.15251111984253 seconds
# ----------------------------------------
# Iteration, for train phase 131/300
# The time taken is 17.4121675491333 seconds
# ----------------------------------------
# Iteration, for train phase 132/300
# The time taken is 16.64626383781433 seconds
# ----------------------------------------
# Iteration, for train phase 133/300
# The time taken is 16.194166898727417 seconds
# ----------------------------------------
# Iteration, for train phase 134/300
# The time taken is 16.95110321044922 seconds
# ----------------------------------------
# Iteration, for train phase 135/300
# The time taken is 17.0885910987854 seconds
# ----------------------------------------
# Iteration, for train phase 136/300
# The time taken is 16.14936876296997 seconds
# ----------------------------------------
# Iteration, for train phase 137/300
# The time taken is 15.991559028625488 seconds
# ----------------------------------------
# Iteration, for train phase 138/300
# The time taken is 17.60374426841736 seconds
# ----------------------------------------
# Iteration, for train phase 139/300
# The time taken is 16.708048582077026 seconds
# ----------------------------------------
# Iteration, for train phase 140/300
# The time taken is 16.182950019836426 seconds
# ----------------------------------------
# Iteration, for train phase 141/300
# The time taken is 16.07508683204651 seconds
# ----------------------------------------
# Iteration, for train phase 142/300
# The time taken is 17.719141244888306 seconds
# ----------------------------------------
# Iteration, for train phase 143/300
# The time taken is 18.16967225074768 seconds
# ----------------------------------------
# Iteration, for train phase 144/300
# The time taken is 17.316641092300415 seconds
# ----------------------------------------
# Iteration, for train phase 145/300
# The time taken is 20.08537220954895 seconds
# ----------------------------------------
# Iteration, for train phase 146/300
# The time taken is 17.625873565673828 seconds
# ----------------------------------------
# Iteration, for train phase 147/300
# The time taken is 16.418450117111206 seconds
# ----------------------------------------
# Iteration, for train phase 148/300
# The time taken is 17.37858486175537 seconds
# ----------------------------------------
# Iteration, for train phase 149/300
# The time taken is 16.861605167388916 seconds
# ----------------------------------------
# Iteration, for train phase 150/300
# The time taken is 16.538439750671387 seconds
# ----------------------------------------
# Iteration, for train phase 151/300
# The time taken is 17.325650215148926 seconds
# ----------------------------------------
# Iteration, for train phase 152/300
# The time taken is 17.259145736694336 seconds
# ----------------------------------------
# Iteration, for train phase 153/300
# The time taken is 17.432436227798462 seconds
# ----------------------------------------
# Iteration, for train phase 154/300
# The time taken is 16.819103956222534 seconds
# ----------------------------------------
# Iteration, for train phase 155/300
# The time taken is 17.180814027786255 seconds
# ----------------------------------------
# Iteration, for train phase 156/300
# The time taken is 16.465818405151367 seconds
# ----------------------------------------
# Iteration, for train phase 157/300
# The time taken is 15.967998504638672 seconds
# ----------------------------------------
# Iteration, for train phase 158/300
# The time taken is 16.9076988697052 seconds
# ----------------------------------------
# Iteration, for train phase 159/300
# The time taken is 17.409996032714844 seconds
# ----------------------------------------
# Iteration, for train phase 160/300
# The time taken is 16.237637758255005 seconds
# ----------------------------------------
# Iteration, for train phase 161/300
# The time taken is 17.588621854782104 seconds
# ----------------------------------------
# Iteration, for train phase 162/300
# The time taken is 17.065473794937134 seconds
# ----------------------------------------
# Iteration, for train phase 163/300
# The time taken is 16.83001446723938 seconds
# ----------------------------------------
# Iteration, for train phase 164/300
# The time taken is 16.407889127731323 seconds
# ----------------------------------------
# Iteration, for train phase 165/300
# The time taken is 17.464009761810303 seconds
# ----------------------------------------
# Iteration, for train phase 166/300
# The time taken is 17.32136344909668 seconds
# ----------------------------------------
# Iteration, for train phase 167/300
# The time taken is 16.60725450515747 seconds
# ----------------------------------------
# Iteration, for train phase 168/300
# The time taken is 16.765135049819946 seconds
# ----------------------------------------
# Iteration, for train phase 169/300
# The time taken is 16.771498680114746 seconds
# ----------------------------------------
# Iteration, for train phase 170/300
# The time taken is 17.49849820137024 seconds
# ----------------------------------------
# Iteration, for train phase 171/300
# The time taken is 16.185503721237183 seconds
# ----------------------------------------
# Iteration, for train phase 172/300
# The time taken is 18.895251989364624 seconds
# ----------------------------------------
# Iteration, for train phase 173/300
# The time taken is 16.320939779281616 seconds
# ----------------------------------------
# Iteration, for train phase 174/300
# The time taken is 16.260313272476196 seconds
# ----------------------------------------
# Iteration, for train phase 175/300
# The time taken is 16.74539613723755 seconds
# ----------------------------------------
# Iteration, for train phase 176/300
# The time taken is 16.489267587661743 seconds
# ----------------------------------------
# Iteration, for train phase 177/300
# The time taken is 16.701185941696167 seconds
# ----------------------------------------
# Iteration, for train phase 178/300
# The time taken is 16.425198793411255 seconds
# ----------------------------------------
# Iteration, for train phase 179/300
# The time taken is 17.09443163871765 seconds
# ----------------------------------------
# Iteration, for train phase 180/300
# The time taken is 17.171874046325684 seconds
# ----------------------------------------
# Iteration, for train phase 181/300
# The time taken is 17.188111782073975 seconds
# ----------------------------------------
# Iteration, for train phase 182/300
# The time taken is 16.552186250686646 seconds
# ----------------------------------------
# Iteration, for train phase 183/300
# The time taken is 16.55817484855652 seconds
# ----------------------------------------
# Iteration, for train phase 184/300
# The time taken is 17.491047143936157 seconds
# ----------------------------------------
# Iteration, for train phase 185/300
# The time taken is 17.90855121612549 seconds
# ----------------------------------------
# Iteration, for train phase 186/300
# The time taken is 18.665240049362183 seconds
# ----------------------------------------
# Iteration, for train phase 187/300
# The time taken is 16.434490442276 seconds
# ----------------------------------------
# Iteration, for train phase 188/300
# The time taken is 16.947319746017456 seconds
# ----------------------------------------
# Iteration, for train phase 189/300
# The time taken is 17.017040252685547 seconds
# ----------------------------------------
# Iteration, for train phase 190/300
# The time taken is 18.48924469947815 seconds
# ----------------------------------------
# Iteration, for train phase 191/300
# The time taken is 16.25050973892212 seconds
# ----------------------------------------
# Iteration, for train phase 192/300
# The time taken is 17.410195350646973 seconds
# ----------------------------------------
# Iteration, for train phase 193/300
# The time taken is 17.079764366149902 seconds
# ----------------------------------------
# Iteration, for train phase 194/300
# The time taken is 16.3962345123291 seconds
# ----------------------------------------
# Iteration, for train phase 195/300
# The time taken is 16.462714433670044 seconds
# ----------------------------------------
# Iteration, for train phase 196/300
# The time taken is 19.178104162216187 seconds
# ----------------------------------------
# Iteration, for train phase 197/300
# The time taken is 18.77344822883606 seconds
# ----------------------------------------
# Iteration, for train phase 198/300
# The time taken is 17.40413546562195 seconds
# ----------------------------------------
# Iteration, for train phase 199/300
# The time taken is 17.38328790664673 seconds
# ----------------------------------------
# Iteration, for train phase 200/300
# The time taken is 17.225473403930664 seconds
# ----------------------------------------
# Iteration, for train phase 201/300
# The time taken is 16.596993923187256 seconds
# ----------------------------------------
# Iteration, for train phase 202/300
# The time taken is 17.011565685272217 seconds
# ----------------------------------------
# Iteration, for train phase 203/300
# The time taken is 17.04493474960327 seconds
# ----------------------------------------
# Iteration, for train phase 204/300
# The time taken is 17.38893985748291 seconds
# ----------------------------------------
# Iteration, for train phase 205/300
# The time taken is 17.26698613166809 seconds
# ----------------------------------------
# Iteration, for train phase 206/300
# The time taken is 17.204323530197144 seconds
# ----------------------------------------
# Iteration, for train phase 207/300
# The time taken is 16.84646964073181 seconds
# ----------------------------------------
# Iteration, for train phase 208/300
# The time taken is 16.368648290634155 seconds
# ----------------------------------------
# Iteration, for train phase 209/300
# The time taken is 19.9096999168396 seconds
# ----------------------------------------
# Iteration, for train phase 210/300
# The time taken is 18.08127498626709 seconds
# ----------------------------------------
# Iteration, for train phase 211/300
# The time taken is 16.729429721832275 seconds
# ----------------------------------------
# Iteration, for train phase 212/300
# The time taken is 17.207797050476074 seconds
# ----------------------------------------
# Iteration, for train phase 213/300
# The time taken is 17.381263971328735 seconds
# ----------------------------------------
# Iteration, for train phase 214/300
# The time taken is 16.397069454193115 seconds
# ----------------------------------------
# Iteration, for train phase 215/300
# The time taken is 17.540867567062378 seconds
# ----------------------------------------
# Iteration, for train phase 216/300
# The time taken is 16.946786880493164 seconds
# ----------------------------------------
# Iteration, for train phase 217/300
# The time taken is 17.268154859542847 seconds
# ----------------------------------------
# Iteration, for train phase 218/300
# The time taken is 17.625113010406494 seconds
# ----------------------------------------
# Iteration, for train phase 219/300
# The time taken is 16.848555088043213 seconds
# ----------------------------------------
# Iteration, for train phase 220/300
# The time taken is 18.123564958572388 seconds
# ----------------------------------------
# Iteration, for train phase 221/300
# The time taken is 17.673369646072388 seconds
# ----------------------------------------
# Iteration, for train phase 222/300
# The time taken is 18.59603977203369 seconds
# ----------------------------------------
# Iteration, for train phase 223/300
# The time taken is 18.17591381072998 seconds
# ----------------------------------------
# Iteration, for train phase 224/300
# The time taken is 18.111552238464355 seconds
# ----------------------------------------
# Iteration, for train phase 225/300
# The time taken is 16.7434401512146 seconds
# ----------------------------------------
# Iteration, for train phase 226/300
# The time taken is 17.8827543258667 seconds
# ----------------------------------------
# Iteration, for train phase 227/300
# The time taken is 17.647698402404785 seconds
# ----------------------------------------
# Iteration, for train phase 228/300
# The time taken is 16.613219022750854 seconds
# ----------------------------------------
# Iteration, for train phase 229/300
# The time taken is 17.498069047927856 seconds
# ----------------------------------------
# Iteration, for train phase 230/300
# The time taken is 17.005829334259033 seconds
# ----------------------------------------
# Iteration, for train phase 231/300
# The time taken is 16.722488164901733 seconds
# ----------------------------------------
# Iteration, for train phase 232/300
# The time taken is 16.53229570388794 seconds
# ----------------------------------------
# Iteration, for train phase 233/300
# The time taken is 18.53279948234558 seconds
# ----------------------------------------
# Iteration, for train phase 234/300
# The time taken is 16.951807260513306 seconds
# ----------------------------------------
# Iteration, for train phase 235/300
# The time taken is 17.61389446258545 seconds
# ----------------------------------------
# Iteration, for train phase 236/300
# The time taken is 17.15823483467102 seconds
# ----------------------------------------
# Iteration, for train phase 237/300
# The time taken is 17.32326626777649 seconds
# ----------------------------------------
# Iteration, for train phase 238/300
# The time taken is 17.271321773529053 seconds
# ----------------------------------------
# Iteration, for train phase 239/300
# The time taken is 16.965984582901 seconds
# ----------------------------------------
# Iteration, for train phase 240/300
# The time taken is 16.994465351104736 seconds
# ----------------------------------------
# Iteration, for train phase 241/300
# The time taken is 16.351413011550903 seconds
# ----------------------------------------
# Iteration, for train phase 242/300
# The time taken is 17.772552967071533 seconds
# ----------------------------------------
# Iteration, for train phase 243/300
# The time taken is 16.38301992416382 seconds
# ----------------------------------------
# Iteration, for train phase 244/300
# The time taken is 16.199926137924194 seconds
# ----------------------------------------
# Iteration, for train phase 245/300
# The time taken is 16.238149404525757 seconds
# ----------------------------------------
# Iteration, for train phase 246/300
# The time taken is 16.794949769973755 seconds
# ----------------------------------------
# Iteration, for train phase 247/300
# The time taken is 16.615535974502563 seconds
# ----------------------------------------
# Iteration, for train phase 248/300
# The time taken is 17.006208896636963 seconds
# ----------------------------------------
# Iteration, for train phase 249/300
# The time taken is 16.794645309448242 seconds
# ----------------------------------------
# Iteration, for train phase 250/300
# The time taken is 17.23557448387146 seconds
# ----------------------------------------
# Iteration, for train phase 251/300
# The time taken is 16.456375122070312 seconds
# ----------------------------------------
# Iteration, for train phase 252/300
# The time taken is 16.7405903339386 seconds
# ----------------------------------------
# Iteration, for train phase 253/300
# The time taken is 16.283591747283936 seconds
# ----------------------------------------
# Iteration, for train phase 254/300
# The time taken is 16.90727972984314 seconds
# ----------------------------------------
# Iteration, for train phase 255/300
# The time taken is 16.624491453170776 seconds
# ----------------------------------------
# Iteration, for train phase 256/300
# The time taken is 16.52259349822998 seconds
# ----------------------------------------
# Iteration, for train phase 257/300
# The time taken is 18.503737211227417 seconds
# ----------------------------------------
# Iteration, for train phase 258/300
# The time taken is 17.876079559326172 seconds
# ----------------------------------------
# Iteration, for train phase 259/300
# The time taken is 16.879014015197754 seconds
# ----------------------------------------
# Iteration, for train phase 260/300
# The time taken is 16.373619556427002 seconds
# ----------------------------------------
# Iteration, for train phase 261/300
# The time taken is 16.690505504608154 seconds
# ----------------------------------------
# Iteration, for train phase 262/300
# The time taken is 16.590441465377808 seconds
# ----------------------------------------
# Iteration, for train phase 263/300
# The time taken is 17.64272165298462 seconds
# ----------------------------------------
# Iteration, for train phase 264/300
# The time taken is 16.62861132621765 seconds
# ----------------------------------------
# Iteration, for train phase 265/300
# The time taken is 16.648117780685425 seconds
# ----------------------------------------
# Iteration, for train phase 266/300
# The time taken is 16.650853395462036 seconds
# ----------------------------------------
# Iteration, for train phase 267/300
# The time taken is 16.568479299545288 seconds
# ----------------------------------------
# Iteration, for train phase 268/300
# The time taken is 16.397640228271484 seconds
# ----------------------------------------
# Iteration, for train phase 269/300
# The time taken is 17.261423587799072 seconds
# ----------------------------------------
# Iteration, for train phase 270/300
# The time taken is 16.72790288925171 seconds
# ----------------------------------------
# Iteration, for train phase 271/300
# The time taken is 16.844337224960327 seconds
# ----------------------------------------
# Iteration, for train phase 272/300
# The time taken is 16.967363357543945 seconds
# ----------------------------------------
# Iteration, for train phase 273/300
# The time taken is 16.798025846481323 seconds
# ----------------------------------------
# Iteration, for train phase 274/300
# The time taken is 17.350443601608276 seconds
# ----------------------------------------
# Iteration, for train phase 275/300
# The time taken is 16.90168809890747 seconds
# ----------------------------------------
# Iteration, for train phase 276/300
# The time taken is 16.665547609329224 seconds
# ----------------------------------------
# Iteration, for train phase 277/300
# The time taken is 17.774675130844116 seconds
# ----------------------------------------
# Iteration, for train phase 278/300
# The time taken is 16.565455198287964 seconds
# ----------------------------------------
# Iteration, for train phase 279/300
# The time taken is 16.875571250915527 seconds
# ----------------------------------------
# Iteration, for train phase 280/300
# The time taken is 18.900866508483887 seconds
# ----------------------------------------
# Iteration, for train phase 281/300
# The time taken is 17.634008407592773 seconds
# ----------------------------------------
# Iteration, for train phase 282/300
# The time taken is 16.51493740081787 seconds
# ----------------------------------------
# Iteration, for train phase 283/300
# The time taken is 17.54443669319153 seconds
# ----------------------------------------
# Iteration, for train phase 284/300
# The time taken is 17.174135446548462 seconds
# ----------------------------------------
# Iteration, for train phase 285/300
# The time taken is 16.530300617218018 seconds
# ----------------------------------------
# Iteration, for train phase 286/300
# The time taken is 16.353338479995728 seconds
# ----------------------------------------
# Iteration, for train phase 287/300
# The time taken is 17.74440336227417 seconds
# ----------------------------------------
# Iteration, for train phase 288/300
# The time taken is 17.236268997192383 seconds
# ----------------------------------------
# Iteration, for train phase 289/300
# The time taken is 16.58355689048767 seconds
# ----------------------------------------
# Iteration, for train phase 290/300
# The time taken is 16.9898624420166 seconds
# ----------------------------------------
# Iteration, for train phase 291/300
# The time taken is 18.132395267486572 seconds
# ----------------------------------------
# Iteration, for train phase 292/300
# The time taken is 17.479806423187256 seconds
# ----------------------------------------
# Iteration, for train phase 293/300
# The time taken is 17.147595405578613 seconds
# ----------------------------------------
# Iteration, for train phase 294/300
# The time taken is 17.47408652305603 seconds
# ----------------------------------------
# Iteration, for train phase 295/300
# The time taken is 16.881941080093384 seconds
# ----------------------------------------
# Iteration, for train phase 296/300
# The time taken is 17.133012533187866 seconds
# ----------------------------------------
# Iteration, for train phase 297/300
# The time taken is 18.470372200012207 seconds
# ----------------------------------------
# Iteration, for train phase 298/300
# The time taken is 18.305699825286865 seconds
# ----------------------------------------
# Iteration, for train phase 299/300
# The time taken is 17.155493021011353 seconds
# ----------------------------------------
# Iteration, for train phase 300/300
# The time taken is 17.637274503707886 seconds
# ----------------------------------------
# Iteration, for validation phase 1/100
# The time taken is 17.187279224395752 seconds
# ----------------------------------------
# Iteration, for validation phase 2/100
# The time taken is 16.04867386817932 seconds
# ----------------------------------------
# Iteration, for validation phase 3/100
# The time taken is 16.680858612060547 seconds
# ----------------------------------------
# Iteration, for validation phase 4/100
# The time taken is 16.7374484539032 seconds
# ----------------------------------------
# Iteration, for validation phase 5/100
# The time taken is 15.702177286148071 seconds
# ----------------------------------------
# Iteration, for validation phase 6/100
# The time taken is 15.828546285629272 seconds
# ----------------------------------------
# Iteration, for validation phase 7/100
# The time taken is 17.06378197669983 seconds
# ----------------------------------------
# Iteration, for validation phase 8/100
# The time taken is 17.286251306533813 seconds
# ----------------------------------------
# Iteration, for validation phase 9/100
# The time taken is 16.4765784740448 seconds
# ----------------------------------------
# Iteration, for validation phase 10/100
# The time taken is 16.117570877075195 seconds
# ----------------------------------------
# Iteration, for validation phase 11/100
# The time taken is 16.743821382522583 seconds
# ----------------------------------------
# Iteration, for validation phase 12/100
# The time taken is 16.363115310668945 seconds
# ----------------------------------------
# Iteration, for validation phase 13/100
# The time taken is 15.410252571105957 seconds
# ----------------------------------------
# Iteration, for validation phase 14/100
# The time taken is 16.564908266067505 seconds
# ----------------------------------------
# Iteration, for validation phase 15/100
# The time taken is 16.642571449279785 seconds
# ----------------------------------------
# Iteration, for validation phase 16/100
# The time taken is 15.903595447540283 seconds
# ----------------------------------------
# Iteration, for validation phase 17/100
# The time taken is 15.952890872955322 seconds
# ----------------------------------------
# Iteration, for validation phase 18/100
# The time taken is 16.73906636238098 seconds
# ----------------------------------------
# Iteration, for validation phase 19/100
# The time taken is 16.334659337997437 seconds
# ----------------------------------------
# Iteration, for validation phase 20/100
# The time taken is 16.00426483154297 seconds
# ----------------------------------------
# Iteration, for validation phase 21/100
# The time taken is 16.108434200286865 seconds
# ----------------------------------------
# Iteration, for validation phase 22/100
# The time taken is 16.78843092918396 seconds
# ----------------------------------------
# Iteration, for validation phase 23/100
# The time taken is 15.450865030288696 seconds
# ----------------------------------------
# Iteration, for validation phase 24/100
# The time taken is 15.826034545898438 seconds
# ----------------------------------------
# Iteration, for validation phase 25/100
# The time taken is 15.805711507797241 seconds
# ----------------------------------------
# Iteration, for validation phase 26/100
# The time taken is 16.13736653327942 seconds
# ----------------------------------------
# Iteration, for validation phase 27/100
# The time taken is 15.354807615280151 seconds
# ----------------------------------------
# Iteration, for validation phase 28/100
# The time taken is 16.4023597240448 seconds
# ----------------------------------------
# Iteration, for validation phase 29/100
# The time taken is 15.892530918121338 seconds
# ----------------------------------------
# Iteration, for validation phase 30/100
# The time taken is 15.601189374923706 seconds
# ----------------------------------------
# Iteration, for validation phase 31/100
# The time taken is 15.350890874862671 seconds
# ----------------------------------------
# Iteration, for validation phase 32/100
# The time taken is 16.33417510986328 seconds
# ----------------------------------------
# Iteration, for validation phase 33/100
# The time taken is 16.063274383544922 seconds
# ----------------------------------------
# Iteration, for validation phase 34/100
# The time taken is 16.0197856426239 seconds
# ----------------------------------------
# Iteration, for validation phase 35/100
# The time taken is 17.32586693763733 seconds
# ----------------------------------------
# Iteration, for validation phase 36/100
# The time taken is 16.006848096847534 seconds
# ----------------------------------------
# Iteration, for validation phase 37/100
# The time taken is 15.944053173065186 seconds
# ----------------------------------------
# Iteration, for validation phase 38/100
# The time taken is 15.81029224395752 seconds
# ----------------------------------------
# Iteration, for validation phase 39/100
# The time taken is 16.387311935424805 seconds
# ----------------------------------------
# Iteration, for validation phase 40/100
# The time taken is 16.39903688430786 seconds
# ----------------------------------------
# Iteration, for validation phase 41/100
# The time taken is 15.907371282577515 seconds
# ----------------------------------------
# Iteration, for validation phase 42/100
# The time taken is 16.299900770187378 seconds
# ----------------------------------------
# Iteration, for validation phase 43/100
# The time taken is 15.438390731811523 seconds
# ----------------------------------------
# Iteration, for validation phase 44/100
# The time taken is 15.74115800857544 seconds
# ----------------------------------------
# Iteration, for validation phase 45/100
# The time taken is 15.30250072479248 seconds
# ----------------------------------------
# Iteration, for validation phase 46/100
# The time taken is 16.145217895507812 seconds
# ----------------------------------------
# Iteration, for validation phase 47/100
# The time taken is 16.386253118515015 seconds
# ----------------------------------------
# Iteration, for validation phase 48/100
# The time taken is 15.80422067642212 seconds
# ----------------------------------------
# Iteration, for validation phase 49/100
# The time taken is 17.288320302963257 seconds
# ----------------------------------------
# Iteration, for validation phase 50/100
# The time taken is 16.184669017791748 seconds
# ----------------------------------------
# Iteration, for validation phase 51/100
# The time taken is 15.638669967651367 seconds
# ----------------------------------------
# Iteration, for validation phase 52/100
# The time taken is 16.014949321746826 seconds
# ----------------------------------------
# Iteration, for validation phase 53/100
# The time taken is 15.580727338790894 seconds
# ----------------------------------------
# Iteration, for validation phase 54/100
# The time taken is 16.207074642181396 seconds
# ----------------------------------------
# Iteration, for validation phase 55/100
# The time taken is 15.9593825340271 seconds
# ----------------------------------------
# Iteration, for validation phase 56/100
# The time taken is 15.755789279937744 seconds
# ----------------------------------------
# Iteration, for validation phase 57/100
# The time taken is 16.193535327911377 seconds
# ----------------------------------------
# Iteration, for validation phase 58/100
# The time taken is 15.676762342453003 seconds
# ----------------------------------------
# Iteration, for validation phase 59/100
# The time taken is 15.831663131713867 seconds
# ----------------------------------------
# Iteration, for validation phase 60/100
# The time taken is 15.760415315628052 seconds
# ----------------------------------------
# Iteration, for validation phase 61/100
# The time taken is 16.488964796066284 seconds
# ----------------------------------------
# Iteration, for validation phase 62/100
# The time taken is 15.61784315109253 seconds
# ----------------------------------------
# Iteration, for validation phase 63/100
# The time taken is 15.494052171707153 seconds
# ----------------------------------------
# Iteration, for validation phase 64/100
# The time taken is 15.792349338531494 seconds
# ----------------------------------------
# Iteration, for validation phase 65/100
# The time taken is 15.94546365737915 seconds
# ----------------------------------------
# Iteration, for validation phase 66/100
# The time taken is 20.33523154258728 seconds
# ----------------------------------------
# Iteration, for validation phase 67/100
# The time taken is 15.380954504013062 seconds
# ----------------------------------------
# Iteration, for validation phase 68/100
# The time taken is 15.770638704299927 seconds
# ----------------------------------------
# Iteration, for validation phase 69/100
# The time taken is 15.852145671844482 seconds
# ----------------------------------------
# Iteration, for validation phase 70/100
# The time taken is 16.158084392547607 seconds
# ----------------------------------------
# Iteration, for validation phase 71/100
# The time taken is 16.223256587982178 seconds
# ----------------------------------------
# Iteration, for validation phase 72/100
# The time taken is 16.040850400924683 seconds
# ----------------------------------------
# Iteration, for validation phase 73/100
# The time taken is 15.354870557785034 seconds
# ----------------------------------------
# Iteration, for validation phase 74/100
# The time taken is 15.658666372299194 seconds
# ----------------------------------------
# Iteration, for validation phase 75/100
# The time taken is 15.958273649215698 seconds
# ----------------------------------------
# Iteration, for validation phase 76/100
# The time taken is 16.374449968338013 seconds
# ----------------------------------------
# Iteration, for validation phase 77/100
# The time taken is 16.17356014251709 seconds
# ----------------------------------------
# Iteration, for validation phase 78/100
# The time taken is 15.730946779251099 seconds
# ----------------------------------------
# Iteration, for validation phase 79/100
# The time taken is 17.259713172912598 seconds
# ----------------------------------------
# Iteration, for validation phase 80/100
# The time taken is 15.494800329208374 seconds
# ----------------------------------------
# Iteration, for validation phase 81/100
# The time taken is 15.461184024810791 seconds
# ----------------------------------------
# Iteration, for validation phase 82/100
# The time taken is 17.107094526290894 seconds
# ----------------------------------------
# Iteration, for validation phase 83/100
# The time taken is 16.774806261062622 seconds
# ----------------------------------------
# Iteration, for validation phase 84/100
# The time taken is 15.813459873199463 seconds
# ----------------------------------------
# Iteration, for validation phase 85/100
# The time taken is 15.640474557876587 seconds
# ----------------------------------------
# Iteration, for validation phase 86/100
# The time taken is 15.935718297958374 seconds
# ----------------------------------------
# Iteration, for validation phase 87/100
# The time taken is 16.441038608551025 seconds
# ----------------------------------------
# Iteration, for validation phase 88/100
# The time taken is 15.826321125030518 seconds
# ----------------------------------------
# Iteration, for validation phase 89/100
# The time taken is 15.550062894821167 seconds
# ----------------------------------------
# Iteration, for validation phase 90/100
# The time taken is 16.117332935333252 seconds
# ----------------------------------------
# Iteration, for validation phase 91/100
# The time taken is 17.037039518356323 seconds
# ----------------------------------------
# Iteration, for validation phase 92/100
# The time taken is 15.689530849456787 seconds
# ----------------------------------------
# Iteration, for validation phase 93/100
# The time taken is 15.896841287612915 seconds
# ----------------------------------------
# Iteration, for validation phase 94/100
# The time taken is 16.15889573097229 seconds
# ----------------------------------------
# Iteration, for validation phase 95/100
# The time taken is 15.182531833648682 seconds
# ----------------------------------------
# Iteration, for validation phase 96/100
# The time taken is 16.12651014328003 seconds
# ----------------------------------------
# Iteration, for validation phase 97/100
# The time taken is 15.633742570877075 seconds
# ----------------------------------------
# Iteration, for validation phase 98/100
# The time taken is 16.959127187728882 seconds
# ----------------------------------------
# Iteration, for validation phase 99/100
# The time taken is 16.386659145355225 seconds
# ----------------------------------------
# Iteration, for validation phase 100/100
# The time taken is 15.53914213180542 seconds
# The accuracy of the model is: 0.9946

# %% [markdown]
# <b>Print out the Accuracy and plot the loss stored in the list <code>loss_list</code> for every iteration and take a screen shot.</b>

# %%
accuracy
# Out:
# 0.9946

# %%
plt.plot(loss_list)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# <h2 id="Question_3">Question 3:Find the misclassified samples</h2>

# %% [markdown]
# <b>Identify the first four misclassified samples using the validation data:</b>

# %%
count = 0
max_item_no = 4
batch_size =1
validation_loader_b1 = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size= batch_size)

for i, (x_test, y_test) in enumerate(validation_loader_b1):
    model.eval()
    z = model(x_test)
    _, yhat = torch.max(z.data, 1)
    if yhat != y_test:
        print("Misclassified, Sample: {} ----> Predicted Value: {} ; Actual Value : {}".format(str(i), str(y_test), str(yhat)))
        count += 1
        if count >= max_item_no:
            break
# Out:
# Misclassified, Sample: 322 ----> Predicted Value: tensor([1]) ; Actual Value : tensor([0])
# Misclassified, Sample: 428 ----> Predicted Value: tensor([1]) ; Actual Value : tensor([0])
# Misclassified, Sample: 500 ----> Predicted Value: tensor([1]) ; Actual Value : tensor([0])
# Misclassified, Sample: 579 ----> Predicted Value: tensor([0]) ; Actual Value : tensor([1])

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/share-notebooks.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork20647850-2022-01-01"> CLICK HERE </a> Click here to see how to share your notebook.

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork20647850-2022-01-01">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                                          |
# | ----------------- | ------- | ---------- | ----------------------------------------------------------- |
# | 2020-09-21        | 2.0     | Shubham    | Migrated Lab to Markdown and added to course repo in GitLab |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>

# %% [markdown]
# Copyright © 2018 <a href="https://cognitiveclass.ai/?utm_medium=dswb&utm_source=bducopyrightlink&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork20647850-2022-01-01&utm_campaign=bdu">cognitiveclass.ai</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork20647850-2022-01-01">MIT License</a>.
